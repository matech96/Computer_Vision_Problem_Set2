# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
left = mpimg.imread("input/pair0-L.png")
right = mpimg.imread("input/pair0-R.png")
size_x, size_y = left.shape

figsize = 16
fig = plt.figure(figsize=(figsize,figsize))
r = fig.add_subplot(1,2,1)
r.set_title(left.shape)
plt.imshow(left, cmap="gray")
r = fig.add_subplot(1,2,2)
r.set_title(right.shape)
plt.imshow(right, cmap="gray")
plt.show()

# %%
import cv2
import numpy as np
print(cv2.__version__)
kernel_size = 8
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=kernel_size)
disparity = stereo.compute(left, right)
plt.imshow(disparity,'gray')
plt.show()
# Out:
# 3.2.0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-45fc9033b4e6> in <module>()
#       4 kernel_size = 8
#       5 stereo = cv2.StereoBM_create(numDisparities=16, blockSize=kernel_size)
# ----> 6 disparity = stereo.compute(left, right)
#       7 plt.imshow(disparity,'gray')
#       8 plt.show()
#
# error: C:\bld\opencv_1498171314629\work\opencv-3.2.0\modules\calib3d\src\stereobm.cpp:1072: error: (-210) Both input images must have CV_8UC1 in function cv::StereoBMImpl::compute
